# %%
# ==============================================================================
# PROJECT: Kaggle Playground Series - S6E2 (Heart Disease)
# MISSION: Hyperparameter Optimization (Corrected Indexing)
# ==============================================================================

# !pip install optuna -q

import pandas as pd
import numpy as np
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from google.colab import drive

# --- STEP 1: LOAD & ALIGN DATA ---
drive.mount('/content/drive')
train = pd.read_csv('/content/drive/MyDrive/Nihal Data/kaggle/S6E1 - heart/train.csv')

target_mapping = {'Absence': 0, 'Presence': 1}
y = train['Heart Disease'].map(target_mapping).reset_index(drop=True)
X = train.drop(['id', 'Heart Disease'], axis=1)

# Categorical Encoding
for col in X.select_dtypes(include=['object']).columns:
    X[col] = X[col].astype('category').cat.codes

# THE FIX: Ensuring X has a clean 0 to N index for .iloc
X = X.reset_index(drop=True)

print(f" Alignment Check: X shape {X.shape}, y shape {y.shape}")

# --- STEP 2: THE OBJECTIVE FUNCTION ---
def objective(trial):
    param = {
        'n_estimators': 1000,
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'tree_method': 'hist',
        'device': 'cuda',
        'eval_metric': 'auc',
        'random_state': 42
    }

    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in skf.split(X, y):
        X_t, X_v = X.iloc[train_idx], X.iloc[val_idx]
        y_t, y_v = y.iloc[train_idx], y.iloc[val_idx]

        model = XGBClassifier(**param, early_stopping_rounds=50)

        # Updated fit syntax for new XGBoost
        model.fit(X_t, y_t, eval_set=[(X_v, y_v)], verbose=False)

        preds = model.predict_proba(X_v)[:, 1]
        scores.append(roc_auc_score(y_v, preds))

    return np.mean(scores)

# --- STEP 3: RUNNING THE SEARCH ---
print(" Launching the Optimizer. Hunting for the Top 100 parameters...")
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20) # Reduced to 20 for faster initial results

print("\n Best Trial Found!")
print(f"  Value (AUC): {study.best_value:.5f}")
print(f"  Best Params: {study.best_params}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [I 2026-02-11 08:11:24,503] A new study created in memory with name: no-name-08527857-cc7f-477f-a5f2-dd07d5cd3ca8
#  Alignment Check: X shape (630000, 13), y shape (630000,)
#  Launching the Optimizer. Hunting for the Top 100 parameters...
# [I 2026-02-11 08:11:36,948] Trial 0 finished with value: 0.9552933083349938 and parameters: {'learning_rate': 0.02753262621868414, 'max_depth': 4, 'subsample': 0.5160507040988652, 'colsample_bytree': 0.7415645082502119, 'min_child_weight': 6}. Best is trial 0 with value: 0.9552933083349938.
# [I 2026-02-11 08:11:53,381] Trial 1 finished with value: 0.9549107989843763 and parameters: {'learning_rate': 0.010602894608873587, 'max_depth': 6, 'subsample': 0.6303585438923989, 'colsample_bytree': 0.7518791191704088, 'min_child_weight': 5}. Best is trial 0 with value: 0.9552933083349938.
# [I 2026-02-11 08:12:04,710] Trial 2 finished with value: 0.9549954084673645 and parameters: {'learning_rate': 0.0453056107957274, 'max_depth': 9, 'subsample': 0.8910474675682108, 'colsample_bytree': 0.6569285404221153, 'min_child_weight': 9}. Best is trial 0 with value: 0.9552933083349938.
# [I 2026-02-11 08:12:12,544] Trial 3 finished with value: 0.9553745344904828 and parameters: {'learning_rate': 0.07592050161393211, 'max_depth': 5, 'subsample': 0.73711590289703, 'colsample_bytree': 0.5442709692519241, 'min_child_weight': 8}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:12:35,200] Trial 4 finished with value: 0.9547889528889036 and parameters: {'learning_rate': 0.015999937738991592, 'max_depth': 9, 'subsample': 0.5212689710189697, 'colsample_bytree': 0.8931740199410667, 'min_child_weight': 1}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:12:42,469] Trial 5 finished with value: 0.9545107519845826 and parameters: {'learning_rate': 0.08051062764475075, 'max_depth': 9, 'subsample': 0.8031496472942712, 'colsample_bytree': 0.9915927491200756, 'min_child_weight': 4}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:12:50,018] Trial 6 finished with value: 0.9548256320161675 and parameters: {'learning_rate': 0.07430801394255154, 'max_depth': 10, 'subsample': 0.9139963132424542, 'colsample_bytree': 0.5745640269413919, 'min_child_weight': 4}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:13:08,742] Trial 7 finished with value: 0.9552836642397852 and parameters: {'learning_rate': 0.019092778124066106, 'max_depth': 7, 'subsample': 0.9242876160653343, 'colsample_bytree': 0.5922457623597409, 'min_child_weight': 3}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:13:17,174] Trial 8 finished with value: 0.954685448388171 and parameters: {'learning_rate': 0.06283652070353438, 'max_depth': 9, 'subsample': 0.903900584769096, 'colsample_bytree': 0.9037512060376885, 'min_child_weight': 9}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:13:24,400] Trial 9 finished with value: 0.9544091642277639 and parameters: {'learning_rate': 0.09522761626033438, 'max_depth': 10, 'subsample': 0.6242010093705088, 'colsample_bytree': 0.8111464629242355, 'min_child_weight': 6}. Best is trial 3 with value: 0.9553745344904828.
# [I 2026-02-11 08:13:36,680] Trial 10 finished with value: 0.9554598415794828 and parameters: {'learning_rate': 0.04648025119188527, 'max_depth': 4, 'subsample': 0.7697583596507068, 'colsample_bytree': 0.511177149059485, 'min_child_weight': 10}. Best is trial 10 with value: 0.9554598415794828.
# [I 2026-02-11 08:13:47,750] Trial 11 finished with value: 0.9553798451602301 and parameters: {'learning_rate': 0.043696130606007196, 'max_depth': 3, 'subsample': 0.7612943565203432, 'colsample_bytree': 0.5114128943390251, 'min_child_weight': 10}. Best is trial 10 with value: 0.9554598415794828.
# [I 2026-02-11 08:13:58,304] Trial 12 finished with value: 0.9553515399681286 and parameters: {'learning_rate': 0.04138105135707402, 'max_depth': 3, 'subsample': 0.7730828097758873, 'colsample_bytree': 0.5305863128076892, 'min_child_weight': 10}. Best is trial 10 with value: 0.9554598415794828.
# [I 2026-02-11 08:14:09,188] Trial 13 finished with value: 0.9552447102090712 and parameters: {'learning_rate': 0.03359056405982855, 'max_depth': 3, 'subsample': 0.6993614144677823, 'colsample_bytree': 0.6596298870632781, 'min_child_weight': 8}. Best is trial 10 with value: 0.9554598415794828.
# [I 2026-02-11 08:14:20,603] Trial 14 finished with value: 0.9554772380958877 and parameters: {'learning_rate': 0.0524336233119705, 'max_depth': 4, 'subsample': 0.8174286638784904, 'colsample_bytree': 0.5096944467506977, 'min_child_weight': 10}. Best is trial 14 with value: 0.9554772380958877.
# [I 2026-02-11 08:14:30,546] Trial 15 finished with value: 0.9553550661539828 and parameters: {'learning_rate': 0.0547789373058706, 'max_depth': 5, 'subsample': 0.9872031700733281, 'colsample_bytree': 0.6362997791987124, 'min_child_weight': 7}. Best is trial 14 with value: 0.9554772380958877.
# [I 2026-02-11 08:14:45,995] Trial 16 finished with value: 0.9553509880192834 and parameters: {'learning_rate': 0.02523884010156147, 'max_depth': 7, 'subsample': 0.8307996388342993, 'colsample_bytree': 0.5047180214798583, 'min_child_weight': 10}. Best is trial 14 with value: 0.9554772380958877.
# [I 2026-02-11 08:14:55,349] Trial 17 finished with value: 0.9553877529726033 and parameters: {'learning_rate': 0.05711019976545649, 'max_depth': 5, 'subsample': 0.6783712847315799, 'colsample_bytree': 0.6143524135120695, 'min_child_weight': 8}. Best is trial 14 with value: 0.9554772380958877.
# [I 2026-02-11 08:15:07,572] Trial 18 finished with value: 0.9553882322998192 and parameters: {'learning_rate': 0.036400797249977954, 'max_depth': 4, 'subsample': 0.8283819761190253, 'colsample_bytree': 0.6948608297931432, 'min_child_weight': 9}. Best is trial 14 with value: 0.9554772380958877.
# [I 2026-02-11 08:15:23,474] Trial 19 finished with value: 0.9553734668208186 and parameters: {'learning_rate': 0.023030311689032787, 'max_depth': 6, 'subsample': 0.8652180080825796, 'colsample_bytree': 0.5677763969775127, 'min_child_weight': 7}. Best is trial 14 with value: 0.9554772380958877.
#  Best Trial Found!
#   Value (AUC): 0.95548
#   Best Params: {'learning_rate': 0.0524336233119705, 'max_depth': 4, 'subsample': 0.8174286638784904, 'colsample_bytree': 0.5096944467506977, 'min_child_weight': 10}
